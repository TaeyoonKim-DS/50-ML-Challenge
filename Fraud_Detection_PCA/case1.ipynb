# %%
# https://www.kaggle.com/code/janiobachmann/credit-fraud-dealing-with-imbalanced-datasets

# %% [markdown]
# 1. 이상거래의 여부를 확인하였을 때 99.9% 는 일반적인 거래이고, 0.01%만이 이상거래임을 확인하였다.
# 2. 결제 금액의 99%이상이 금액이 낮은 부분에서 이루어졌다는 것을 확인하였다. --> 이상거래라고 하더라도 금액이 낮을 수 있다.
# 3. 결제 시기를 확인하였는데 생각보다 균등하게 이루어져 있었다.
# 4. 시간과 금액이 다른 value들과 같은 스케일상에 있지 않으므로 스케일링을 진행하도록 한다.
# 5. Class target밸류를 드롭하고, 층화계층 KFold샘플링을 한다. - Train과 Test set을 적절하게 나눈다.
# 6. dataset을 섞은 후에, 같은 갯수만큼 non fraud transaction에서 undersampling을 진행한다.
# 7.
