# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from warnings import filterwarnings

filterwarnings("ignore")
# %matplotlib inline

# %%
df= pd.read_csv("data/data.csv")

# %%
df.shape
# Out:
# (200000, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 16 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Campaign_ID       200000 non-null  int64
#  1   Company           200000 non-null  object
#  2   Campaign_Type     200000 non-null  object
#  3   Target_Audience   200000 non-null  object
#  4   Duration          200000 non-null  object
#  5   Channel_Used      200000 non-null  object
#  6   Conversion_Rate   200000 non-null  float64
#  7   Acquisition_Cost  200000 non-null  object
#  8   ROI               200000 non-null  float64
#  9   Location          200000 non-null  object
#  10  Language          200000 non-null  object
#  11  Clicks            200000 non-null  int64
#  12  Impressions       200000 non-null  int64
#  13  Engagement_Score  200000 non-null  int64
#  14  Customer_Segment  200000 non-null  object
#  15  Date              200000 non-null  object
# ...

# %%
df['Date'] = pd.to_datetime(df['Date'], format = '%Y-%m-%d')
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month
df['Day'] = df['Date'].dt.day
df
# Out:
#         Campaign_ID              Company Campaign_Type Target_Audience  \
# 0                 1  Innovate Industries         Email       Men 18-24
# 1                 2       NexGen Systems         Email     Women 35-44
# 2                 3    Alpha Innovations    Influencer       Men 25-34
# 3                 4   DataTech Solutions       Display        All Ages
# 4                 5       NexGen Systems         Email       Men 25-34
# ...             ...                  ...           ...             ...
# 199995       199996             TechCorp       Display        All Ages
# 199996       199997   DataTech Solutions         Email       Men 25-34
# 199997       199998   DataTech Solutions  Social Media       Men 18-24
# 199998       199999  Innovate Industries    Influencer        All Ages
# 199999       200000  Innovate Industries  Social Media     Women 35-44
#
#        Duration Channel_Used  Conversion_Rate Acquisition_Cost   ROI  \
# ...

# %%
list_cast_as_object = ['Campaign_ID']
for column in list_cast_as_object:
    df[column] = df[column].astype('object')

# %%
for column_name in df.columns:
    print(column_name, df[column_name].dtype, df[column_name].unique())
# Out:
# Campaign_ID object [1 2 3 ... 199998 199999 200000]
# Company object ['Innovate Industries' 'NexGen Systems' 'Alpha Innovations'
#  'DataTech Solutions' 'TechCorp']
# Campaign_Type object ['Email' 'Influencer' 'Display' 'Search' 'Social Media']
# Target_Audience object ['Men 18-24' 'Women 35-44' 'Men 25-34' 'All Ages' 'Women 25-34']
# Duration object ['30 days' '60 days' '15 days' '45 days']
# Channel_Used object ['Google Ads' 'YouTube' 'Instagram' 'Website' 'Facebook' 'Email']
# Conversion_Rate float64 [0.04 0.12 0.07 0.11 0.05 0.13 0.08 0.09 0.14 0.02 0.06 0.01 0.03 0.1
#  0.15]
# Acquisition_Cost object ['$16,174.00' '$11,566.00' '$10,200.00' ... '$14,111.00' '$13,941.00'
#  '$15,040.00']
# ROI float64 [6.29 5.61 7.18 5.55 6.5  4.36 2.86 6.73 3.78 3.49 3.59 4.91 7.06 5.28
#  2.91 4.53 4.48 6.08 3.83 7.99 6.21 2.12 7.31 6.03 6.23 3.29 7.12 3.61
#  2.77 6.83 4.42 2.71 7.81 2.51 7.24 2.62 2.21 6.97 4.57 3.44 5.6  4.77
# ...

# %%
# df['Acquisition_Cost'] = df['Acquisition_Cost'].str.replace('$','').str.replace(',','').astype(float)
# df['Duration'] = df['Duration'].str.replace(' days', '').astype(int)

# %%
list_categorical_columns = df.select_dtypes(include=['object']).columns.tolist()
list_numerical_columns = df.select_dtypes(include=['float64, int64']).columns.tolist()

# %%
df.sample(5)
# Out:
#        Campaign_ID              Company Campaign_Type Target_Audience  \
# 106412      106413    Alpha Innovations        Search       Men 18-24
# 61916        61917  Innovate Industries  Social Media     Women 25-34
# 86389        86390    Alpha Innovations       Display        All Ages
# 69772        69773  Innovate Industries        Search       Men 18-24
# 127122      127123             TechCorp         Email       Men 18-24
#
#        Duration Channel_Used  Conversion_Rate Acquisition_Cost   ROI  \
# 106412  15 days      YouTube             0.10        $9,801.00  2.21
# 61916   15 days        Email             0.02        $8,124.00  5.10
# 86389   60 days        Email             0.13       $14,071.00  5.68
# 69772   30 days     Facebook             0.04        $7,921.00  2.32
# 127122  15 days   Google Ads             0.14       $17,578.00  4.03
#
#            Location Language  Clicks  Impressions  Engagement_Score  \
# ...
